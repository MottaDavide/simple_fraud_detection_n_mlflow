# %% [markdown]
# # PROBLEM STATEMENT
# There is a room with a television and people come in and out of the room to watch it; the television is on only when there is at least one person in the room.
#
# For each person that enters the room, we record the start and end time, represented as a two-element array containing the starting time (inclusive) and ending time (exclusive), with times as integers (you can think of hours, or minutes, or any interval you like).
#
# We want to know how long the television is on.

# %% [markdown]
# ## example
# For instance, given the list of intervals (1 4), (6 8), (2 4), (7 9), the television is on at times 1, 2, 3 from the first interval, times 6 and 7 from the second interval, times 2 and 3 from the third interval, and times 7 and 8 from the first (last?) interval, a total of 6 times the television is on (at times 1, 2, 3, 6, 7 and 8).
#
# *gen_intervals* function can generate random intervals

# %% [markdown]
# ## task
# Your task is to write a python function that takes a list of intervals and returns the number of times at which the television is on.

# %%
from random import randint

def gen_intervals(length):
    """
    create random intervals
    """
    intervals = []
    for i in range(length):
        a = randint(i, i+5)
        b = randint(i, i+5)
        if a < b :
            intervals.append((a, b))
        elif b < a:
            intervals.append((b, a))
        else: # a == b
            intervals.append((a, b+1))
    return intervals
        
# intervals = [(1, 4), (6, 8), (2, 4), (7, 9)]
intervals = gen_intervals(10)

# %%
intervals
# Out:
# [(2, 4),
#  (3, 4),
#  (2, 7),
#  (7, 8),
#  (6, 9),
#  (5, 8),
#  (6, 10),
#  (9, 10),
#  (10, 11),
#  (11, 13)]

# %% [markdown]
# ## Not optimized function.
# Create a function in the quickest way possible, not the most optimized one. The idea is to expand each interval (a, b) into the list of times [a, a+1, a+2, ..., b-1], concatenate all these expanded lists, and then count the number of unique times in the concatenated list.
#
#
# ### Computationl cost
# n = number of intervals
#
# k = average or max length of intervals. In this exercise k = 5 (k << n in general)
#
# - **expanding an interval**: O(k) since k is the worst case length of an interval (or the average length)
# - **expanding all intervals**: O(n * k) since we have n intervals to expand
# - **concatenating all expanded lists**: O(n * k) since we have n lists of average length k to concatenate
# - **counting unique times**: O(m) where m is the length of the concatenated list, which is O(n*k) in the worst case (if all intervals are disjoint)
# - **total cost**: O(n * k) + O(n * k) + O(n * k) = O(n * k). Since k is fixed and small compared to n, we can simplify this to O(n).
#
#
# Moreover, this function allocate really "huge" lists in memory, which is not optimal.

# %%
from typing import List, Tuple
from functools import wraps
from time import time

# %%
def time_tracker(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        
        start = time()
        result = func(*args, **kwargs)
        end = time()
        print(f"Function {func.__name__} took {end - start:.6f} seconds")
        return result, end-start
    return wrapper

# %%
@time_tracker
def count_times(intervals: List[Tuple[int, int]]) -> int:
    """
    Count the total length covered by the given intervals. This will count the total time the television is on.

    Args:
        intervals (List[Tuple[int, int]]): list of tuples (a,b) representing intervals [a,b)

    Returns:
        int: total time covered by the intervals
    """
    
    def expand_interval(interval: List[int]) -> List[int]:
        """
        Expand an interval [a,b) into a list of integers [a, a+1, ..., b-1]

        Args:
            interval (List[int]): interval [a,b)

        Returns:
            List[int]: list of integers [a, a+1, ..., b-1]
        """
        return list(range(interval[0], interval[1]))
    
    if not intervals:
        return 0
        
    return len(set(sum(map(expand_interval, intervals), [])))


count_times(intervals)[0]
# Out:
# Function count_times took 0.000011 seconds
# 11

# %% [markdown]
# ## Optimized function
# Let's suppose *n* and *k* very big ( k >> logn). Let's try to optimize the function above. The idea is exploiting the sorting (computational cost O(nlogn) and it is very optimized since it exploits C which is fast) and finding the overlapping intervals. Then sum up the lengths of the new non-overlapping intervals.
#
#
# ### Computationl cost
# n = number of intervals
#
# k = average or max length of intervals. In this exercise k = 5(k << n in general)
#
# - **sorting**: O(nlogn)
# - **'for' cycle**: O(n) since we have n intervals to check
# - **total cost**: O(nlogn) + O(n) = O(nlogn) since nlogn is the dominant term.

# %%
@time_tracker
def optimized_count_times(intervals: List[Tuple[int, int]]) -> int:
    """
    Optimized version: count the total length covered by the given intervals. This will count the total time the television is on.
    1) Sort the intervals by their start time.
    2) Merge overlapping intervals.
    3) Sum the lengths of the merged intervals.

    Args:
        intervals (List[Tuple[int, int]]): list of tuples (a,b) representing intervals [a,b)

    Returns:
        int: total time covered by the intervals
    """
    if not intervals:
        return 0
    

    intervals.sort(key=lambda x: x[0]) # Thus each overlap can only be with the next interval

    merged = []
    prev_start, prev_end = intervals[0]

    for start, end in intervals[1:]:
        if start <= prev_end:  # overlap
            prev_end = max(prev_end, end)
        else:  # no overlap, save previous
            merged.append((prev_start, prev_end))
            prev_start, prev_end = start, end


    merged.append((prev_start, prev_end))


    return sum(end - start for start, end in merged)
            
    
    
optimized_count_times(intervals)[0]
# Out:
# Function optimized_count_times took 0.000009 seconds
# 11

# %%
for n in range (5, 10001, 100):
    print("Number of intervals:", n)
    intervals = gen_intervals(n)


    op_count = optimized_count_times(intervals)
    count = count_times(intervals)

    assert op_count[0] == count[0], f"Optimized: {op_count[0]}, Original: {count[0]}"
    
    print("-"*40)
    print("\n")
# Out:
# Number of intervals: 5
# Function optimized_count_times took 0.000006 seconds
# Function count_times took 0.000007 seconds
# ----------------------------------------
#
#
# Number of intervals: 105
# Function optimized_count_times took 0.000021 seconds
# Function count_times took 0.000047 seconds
# ----------------------------------------
#
#
# Number of intervals: 205
# Function optimized_count_times took 0.000034 seconds
# Function count_times took 0.000097 seconds
# ----------------------------------------
#
#
# Number of intervals: 305
# Function optimized_count_times took 0.000227 seconds
# Function count_times took 0.000458 seconds
# ----------------------------------------
#
#
# Number of intervals: 405
# Function optimized_count_times took 0.000108 seconds
# Function count_times took 0.000295 seconds
# ----------------------------------------
#
#
# Number of intervals: 505
# Function optimized_count_times took 0.000217 seconds
# Function count_times took 0.002127 seconds
# ----------------------------------------
#
#
# Number of intervals: 605
# Function optimized_count_times took 0.000115 seconds
# Function count_times took 0.000973 seconds
# ----------------------------------------
#
#
# Number of intervals: 705
# Function optimized_count_times took 0.000166 seconds
# Function count_times took 0.001014 seconds
# ----------------------------------------
#
#
# Number of intervals: 805
# Function optimized_count_times took 0.000146 seconds
# Function count_times took 0.001278 seconds
# ----------------------------------------
#
#
# Number of intervals: 905
# Function optimized_count_times took 0.000168 seconds
# Function count_times took 0.004579 seconds
# ----------------------------------------
#
#
# Number of intervals: 1005
# Function optimized_count_times took 0.000170 seconds
# Function count_times took 0.002986 seconds
# ----------------------------------------
#
#
# Number of intervals: 1105
# Function optimized_count_times took 0.000194 seconds
# Function count_times took 0.002124 seconds
# ----------------------------------------
#
#
# Number of intervals: 1205
# Function optimized_count_times took 0.000208 seconds
# Function count_times took 0.002063 seconds
# ----------------------------------------
#
#
# Number of intervals: 1305
# Function optimized_count_times took 0.000225 seconds
# Function count_times took 0.002715 seconds
# ----------------------------------------
#
#
# Number of intervals: 1405
# Function optimized_count_times took 0.000232 seconds
# Function count_times took 0.004281 seconds
# ----------------------------------------
#
#
# Number of intervals: 1505
# Function optimized_count_times took 0.000245 seconds
# Function count_times took 0.005771 seconds
# ----------------------------------------
#
#
# Number of intervals: 1605
# Function optimized_count_times took 0.000575 seconds
# Function count_times took 0.009551 seconds
# ----------------------------------------
#
#
# Number of intervals: 1705
# Function optimized_count_times took 0.000284 seconds
# Function count_times took 0.008490 seconds
# ----------------------------------------
#
#
# Number of intervals: 1805
# Function optimized_count_times took 0.000663 seconds
# Function count_times took 0.007551 seconds
# ----------------------------------------
#
#
# Number of intervals: 1905
# Function optimized_count_times took 0.000321 seconds
# Function count_times took 0.007729 seconds
# ----------------------------------------
#
#
# Number of intervals: 2005
# Function optimized_count_times took 0.000331 seconds
# Function count_times took 0.007872 seconds
# ----------------------------------------
#
#
# Number of intervals: 2105
# Function optimized_count_times took 0.000806 seconds
# Function count_times took 0.011228 seconds
# ----------------------------------------
#
#
# Number of intervals: 2205
# Function optimized_count_times took 0.000365 seconds
# Function count_times took 0.009877 seconds
# ----------------------------------------
#
#
# Number of intervals: 2305
# Function optimized_count_times took 0.000370 seconds
# Function count_times took 0.013195 seconds
# ----------------------------------------
#
#
# Number of intervals: 2405
# Function optimized_count_times took 0.000631 seconds
# Function count_times took 0.010950 seconds
# ----------------------------------------
#
#
# Number of intervals: 2505
# Function optimized_count_times took 0.000423 seconds
# Function count_times took 0.013893 seconds
# ----------------------------------------
#
#
# Number of intervals: 2605
# Function optimized_count_times took 0.000426 seconds
# Function count_times took 0.015347 seconds
# ----------------------------------------
#
#
# Number of intervals: 2705
# Function optimized_count_times took 0.000781 seconds
# Function count_times took 0.016375 seconds
# ----------------------------------------
#
#
# Number of intervals: 2805
# Function optimized_count_times took 0.000449 seconds
# Function count_times took 0.017843 seconds
# ----------------------------------------
#
#
# Number of intervals: 2905
# Function optimized_count_times took 0.000639 seconds
# Function count_times took 0.019602 seconds
# ----------------------------------------
#
#
# Number of intervals: 3005
# Function optimized_count_times took 0.000484 seconds
# Function count_times took 0.018913 seconds
# ----------------------------------------
#
#
# Number of intervals: 3105
# Function optimized_count_times took 0.000653 seconds
# Function count_times took 0.026026 seconds
# ----------------------------------------
#
#
# Number of intervals: 3205
# Function optimized_count_times took 0.000518 seconds
# Function count_times took 0.021410 seconds
# ----------------------------------------
#
#
# Number of intervals: 3305
# Function optimized_count_times took 0.000524 seconds
# Function count_times took 0.025032 seconds
# ----------------------------------------
#
#
# Number of intervals: 3405
# Function optimized_count_times took 0.000649 seconds
# Function count_times took 0.028293 seconds
# ----------------------------------------
#
#
# Number of intervals: 3505
# Function optimized_count_times took 0.000640 seconds
# Function count_times took 0.024719 seconds
# ----------------------------------------
#
#
# Number of intervals: 3605
# Function optimized_count_times took 0.000757 seconds
# Function count_times took 0.047101 seconds
# ----------------------------------------
#
#
# Number of intervals: 3705
# Function optimized_count_times took 0.001368 seconds
# Function count_times took 0.038798 seconds
# ----------------------------------------
#
#
# Number of intervals: 3805
# Function optimized_count_times took 0.000617 seconds
# Function count_times took 0.031831 seconds
# ----------------------------------------
#
#
# Number of intervals: 3905
# Function optimized_count_times took 0.000942 seconds
# Function count_times took 0.041004 seconds
# ----------------------------------------
#
#
# Number of intervals: 4005
# Function optimized_count_times took 0.001849 seconds
# Function count_times took 0.045823 seconds
# ----------------------------------------
#
#
# Number of intervals: 4105
# Function optimized_count_times took 0.000653 seconds
# Function count_times took 0.045207 seconds
# ----------------------------------------
#
#
# Number of intervals: 4205
# Function optimized_count_times took 0.000665 seconds
# Function count_times took 0.038559 seconds
# ----------------------------------------
#
#
# Number of intervals: 4305
# Function optimized_count_times took 0.000704 seconds
# Function count_times took 0.039680 seconds
# ----------------------------------------
#
#
# Number of intervals: 4405
# Function optimized_count_times took 0.000743 seconds
# Function count_times took 0.044791 seconds
# ----------------------------------------
#
#
# Number of intervals: 4505
# Function optimized_count_times took 0.000754 seconds
# Function count_times took 0.045888 seconds
# ----------------------------------------
#
#
# Number of intervals: 4605
# Function optimized_count_times took 0.000717 seconds
# Function count_times took 0.044931 seconds
# ----------------------------------------
#
#
# Number of intervals: 4705
# Function optimized_count_times took 0.000747 seconds
# Function count_times took 0.048862 seconds
# ----------------------------------------
#
#
# Number of intervals: 4805
# Function optimized_count_times took 0.000787 seconds
# Function count_times took 0.050563 seconds
# ----------------------------------------
#
#
# Number of intervals: 4905
# Function optimized_count_times took 0.000773 seconds
# Function count_times took 0.051438 seconds
# ----------------------------------------
#
#
# Number of intervals: 5005
# Function optimized_count_times took 0.000780 seconds
# Function count_times took 0.093074 seconds
# ----------------------------------------
#
#
# Number of intervals: 5105
# Function optimized_count_times took 0.001314 seconds
# Function count_times took 0.070220 seconds
# ----------------------------------------
#
#
# Number of intervals: 5205
# Function optimized_count_times took 0.000799 seconds
# Function count_times took 0.058301 seconds
# ----------------------------------------
#
#
# Number of intervals: 5305
# Function optimized_count_times took 0.000841 seconds
# Function count_times took 0.061049 seconds
# ----------------------------------------
#
#
# Number of intervals: 5405
# Function optimized_count_times took 0.001067 seconds
# Function count_times took 0.063336 seconds
# ----------------------------------------
#
#
# Number of intervals: 5505
# Function optimized_count_times took 0.000876 seconds
# Function count_times took 0.077491 seconds
# ----------------------------------------
#
#
# Number of intervals: 5605
# Function optimized_count_times took 0.000901 seconds
# Function count_times took 0.060973 seconds
# ----------------------------------------
#
#
# Number of intervals: 5705
# Function optimized_count_times took 0.000921 seconds
# Function count_times took 0.071164 seconds
# ----------------------------------------
#
#
# Number of intervals: 5805
# Function optimized_count_times took 0.000883 seconds
# Function count_times took 0.069351 seconds
# ----------------------------------------
#
#
# Number of intervals: 5905
# Function optimized_count_times took 0.000924 seconds
# Function count_times took 0.074887 seconds
# ----------------------------------------
#
#
# Number of intervals: 6005
# Function optimized_count_times took 0.000917 seconds
# Function count_times took 0.073997 seconds
# ----------------------------------------
#
#
# Number of intervals: 6105
# Function optimized_count_times took 0.001069 seconds
# Function count_times took 0.081846 seconds
# ----------------------------------------
#
#
# Number of intervals: 6205
# Function optimized_count_times took 0.000928 seconds
# Function count_times took 0.081442 seconds
# ----------------------------------------
#
#
# Number of intervals: 6305
# Function optimized_count_times took 0.000993 seconds
# Function count_times took 0.085543 seconds
# ----------------------------------------
#
#
# Number of intervals: 6405
# Function optimized_count_times took 0.001049 seconds
# Function count_times took 0.088062 seconds
# ----------------------------------------
#
#
# Number of intervals: 6505
# Function optimized_count_times took 0.001032 seconds
# Function count_times took 0.092144 seconds
# ----------------------------------------
#
#
# Number of intervals: 6605
# Function optimized_count_times took 0.001081 seconds
# Function count_times took 0.093908 seconds
# ----------------------------------------
#
#
# Number of intervals: 6705
# Function optimized_count_times took 0.001022 seconds
# Function count_times took 0.097966 seconds
# ----------------------------------------
#
#
# Number of intervals: 6805
# Function optimized_count_times took 0.001092 seconds
# Function count_times took 0.100006 seconds
# ----------------------------------------
#
#
# Number of intervals: 6905
# Function optimized_count_times took 0.001148 seconds
# Function count_times took 0.105246 seconds
# ----------------------------------------
#
#
# Number of intervals: 7005
# Function optimized_count_times took 0.001087 seconds
# Function count_times took 0.106383 seconds
# ----------------------------------------
#
#
# Number of intervals: 7105
# Function optimized_count_times took 0.001078 seconds
# Function count_times took 0.109164 seconds
# ----------------------------------------
#
#
# Number of intervals: 7205
# Function optimized_count_times took 0.001183 seconds
# Function count_times took 0.113135 seconds
# ----------------------------------------
#
#
# Number of intervals: 7305
# Function optimized_count_times took 0.001149 seconds
# Function count_times took 0.119994 seconds
# ----------------------------------------
#
#
# Number of intervals: 7405
# Function optimized_count_times took 0.001107 seconds
# Function count_times took 0.127693 seconds
# ----------------------------------------
#
#
# Number of intervals: 7505
# Function optimized_count_times took 0.001119 seconds
# Function count_times took 0.123491 seconds
# ----------------------------------------
#
#
# Number of intervals: 7605
# Function optimized_count_times took 0.001190 seconds
# Function count_times took 0.127818 seconds
# ----------------------------------------
#
#
# Number of intervals: 7705
# Function optimized_count_times took 0.001351 seconds
# Function count_times took 0.155501 seconds
# ----------------------------------------
#
#
# Number of intervals: 7805
# Function optimized_count_times took 0.001245 seconds
# Function count_times took 0.134024 seconds
# ----------------------------------------
#
#
# Number of intervals: 7905
# Function optimized_count_times took 0.001403 seconds
# Function count_times took 0.138958 seconds
# ----------------------------------------
#
#
# Number of intervals: 8005
# Function optimized_count_times took 0.001266 seconds
# Function count_times took 0.137368 seconds
# ----------------------------------------
#
#
# Number of intervals: 8105
# Function optimized_count_times took 0.001448 seconds
# Function count_times took 0.144608 seconds
# ----------------------------------------
#
#
# Number of intervals: 8205
# Function optimized_count_times took 0.001420 seconds
# Function count_times took 0.156798 seconds
# ----------------------------------------
#
#
# Number of intervals: 8305
# Function optimized_count_times took 0.001557 seconds
# Function count_times took 0.156138 seconds
# ----------------------------------------
#
#
# Number of intervals: 8405
# Function optimized_count_times took 0.001291 seconds
# Function count_times took 0.155380 seconds
# ----------------------------------------
#
#
# Number of intervals: 8505
# Function optimized_count_times took 0.001463 seconds
# Function count_times took 0.151236 seconds
# ----------------------------------------
#
#
# Number of intervals: 8605
# Function optimized_count_times took 0.001342 seconds
# Function count_times took 0.171378 seconds
# ----------------------------------------
#
#
# Number of intervals: 8705
# Function optimized_count_times took 0.001684 seconds
# Function count_times took 0.173735 seconds
# ----------------------------------------
#
#
# Number of intervals: 8805
# Function optimized_count_times took 0.001389 seconds
# Function count_times took 0.176534 seconds
# ----------------------------------------
#
#
# Number of intervals: 8905
# Function optimized_count_times took 0.001655 seconds
# Function count_times took 0.185530 seconds
# ----------------------------------------
#
#
# Number of intervals: 9005
# Function optimized_count_times took 0.001550 seconds
# Function count_times took 0.181763 seconds
# ----------------------------------------
#
#
# Number of intervals: 9105
# Function optimized_count_times took 0.001629 seconds
# Function count_times took 0.190111 seconds
# ----------------------------------------
#
#
# Number of intervals: 9205
# Function optimized_count_times took 0.001450 seconds
# Function count_times took 0.188603 seconds
# ----------------------------------------
#
#
# Number of intervals: 9305
# Function optimized_count_times took 0.001598 seconds
# Function count_times took 0.188652 seconds
# ----------------------------------------
#
#
# Number of intervals: 9405
# Function optimized_count_times took 0.001501 seconds
# Function count_times took 0.206648 seconds
# ----------------------------------------
#
#
# Number of intervals: 9505
# Function optimized_count_times took 0.001544 seconds
# Function count_times took 0.207140 seconds
# ----------------------------------------
#
#
# Number of intervals: 9605
# Function optimized_count_times took 0.001509 seconds
# Function count_times took 0.210526 seconds
# ----------------------------------------
#
#
# Number of intervals: 9705
# Function optimized_count_times took 0.001585 seconds
# Function count_times took 0.211379 seconds
# ----------------------------------------
#
#
# Number of intervals: 9805
# Function optimized_count_times took 0.001606 seconds
# Function count_times took 0.210628 seconds
# ----------------------------------------
#
#
# Number of intervals: 9905
# Function optimized_count_times took 0.001623 seconds
# Function count_times took 0.274322 seconds
# ----------------------------------------
