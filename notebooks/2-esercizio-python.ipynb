# %% [markdown]
# # PROBLEM STATEMENT
# There is a room with a television and people come in and out of the room to watch it; the television is on only when there is at least one person in the room.
#
# For each person that enters the room, we record the start and end time, represented as a two-element array containing the starting time (inclusive) and ending time (exclusive), with times as integers (you can think of hours, or minutes, or any interval you like).
#
# We want to know how long the television is on.

# %% [markdown]
# ## example
# For instance, given the list of intervals (1 4), (6 8), (2 4), (7 9), the television is on at times 1, 2, 3 from the first interval, times 6 and 7 from the second interval, times 2 and 3 from the third interval, and times 7 and 8 from the first (last?) interval, a total of 6 times the television is on (at times 1, 2, 3, 6, 7 and 8).
#
# *gen_intervals* function can generate random intervals

# %% [markdown]
# ## task
# Your task is to write a python function that takes a list of intervals and returns the number of times at which the television is on.

# %%
from random import randint

def gen_intervals(length):
    """
    create random intervals
    """
    intervals = []
    for i in range(length):
        a = randint(i, i+5)
        b = randint(i, i+5)
        if a < b :
            intervals.append((a, b))
        elif b < a:
            intervals.append((b, a))
        else: # a == b
            intervals.append((a, b+1))
    return intervals
        
# intervals = [(1, 4), (6, 8), (2, 4), (7, 9)]
intervals = gen_intervals(10)

# %%
intervals
# Out:
# [(0, 4),
#  (5, 6),
#  (6, 7),
#  (7, 8),
#  (4, 5),
#  (5, 9),
#  (6, 11),
#  (7, 12),
#  (12, 13),
#  (12, 14)]

# %% [markdown]
# ## Not optimized function.
# Create a function in the quickest way possible, not the most optimized one. The idea is to expand each interval (a, b) into the list of times [a, a+1, a+2, ..., b-1], concatenate all these expanded lists, and then count the number of unique times in the concatenated list.
#
#
# ### Computationl cost
# n = number of intervals
#
# k = average or max length of intervals. In this exercise k = 5 (k << n in general)
#
# - **expanding an interval**: O(k) since k is the worst case length of an interval (or the average length)
# - **expanding all intervals**: O(n * k) since we have n intervals to expand
# - **concatenating all expanded lists**: O(n * k) since we have n lists of average length k to concatenate
# - **counting unique times**: O(m) where m is the length of the concatenated list, which is O(n*k) in the worst case (if all intervals are disjoint)
# - **total cost**: O(n * k) + O(n * k) + O(n * k) = O(n * k). Since k is fixed and small compared to n, we can simplify this to O(n).
#
#
# Moreover, this function allocate really "huge" lists in memory, which is not optimal.

# %%
from typing import List, Tuple
from functools import wraps
from time import time

# %%
def time_tracker(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        
        start = time()
        result = func(*args, **kwargs)
        end = time()
        print(f"Function {func.__name__} took {end - start:.6f} seconds")
        return result, end-start
    return wrapper

# %%
@time_tracker
def count_times(intervals: List[Tuple[int, int]]) -> int:
    """
    Count the total length covered by the given intervals. This will count the total time the television is on.

    Args:
        intervals (List[Tuple[int, int]]): list of tuples (a,b) representing intervals [a,b)

    Returns:
        int: total time covered by the intervals
    """
    
    def expand_interval(interval: List[int]) -> List[int]:
        """
        Expand an interval [a,b) into a list of integers [a, a+1, ..., b-1]

        Args:
            interval (List[int]): interval [a,b)

        Returns:
            List[int]: list of integers [a, a+1, ..., b-1]
        """
        return list(range(interval[0], interval[1]))
    
    if not intervals:
        return 0
        
    return len(set(sum(map(expand_interval, intervals), [])))


count_times(intervals)[0]
# Out:
# Function count_times took 0.000000 seconds
# 14

# %% [markdown]
# ## Optimized function
# Let's suppose *n* and *k* very big ( k >> logn). Let's try to optimize the function above. The idea is exploiting the sorting (computational cost O(nlogn) and it is very optimized since it exploits C which is fast) and finding the overlapping intervals. Then sum up the lengths of the new non-overlapping intervals.
#
#
# ### Computationl cost
# n = number of intervals
#
# k = average or max length of intervals. In this exercise k = 5(k << n in general)
#
# - **sorting**: O(nlogn)
# - **'for' cycle**: O(n) since we have n intervals to check
# - **total cost**: O(nlogn) + O(n) = O(nlogn) since nlogn is the dominant term.
# - The memeory cost is related to the lenght of intervals

# %%
@time_tracker
def optimized_count_times(intervals: List[Tuple[int, int]]) -> int:
    """
    Optimized version: count the total length covered by the given intervals. This will count the total time the television is on.
    1) Sort the intervals by their start time.
    2) Merge overlapping intervals.
    3) Sum the lengths of the merged intervals.

    Args:
        intervals (List[Tuple[int, int]]): list of tuples (a,b) representing intervals [a,b)

    Returns:
        int: total time covered by the intervals
    """
    if not intervals:
        return 0
    

    intervals.sort(key=lambda x: x[0]) # Thus each overlap can only be with the next interval


    prev_start, prev_end = intervals[0]
    total = 0

    for start, end in intervals[1:]:
        if start <= prev_end:  # if there is an overlap then the 'end' could be extended
            prev_end = max(prev_end, end)
        else:  # if no overlap, calculate the length of the previous interval and move to the next
            total += prev_end - prev_start
            prev_start, prev_end = start, end
    total += prev_end - prev_start # add the last interval
    return total


            
    
    
optimized_count_times(intervals)[0]
# Out:
# Function optimized_count_times took 0.000000 seconds
# 14

# %%
for n in range (5, 10001, 100):
    print("Number of intervals:", n)
    intervals = gen_intervals(n)


    op_count = optimized_count_times(intervals)
    count = count_times(intervals)

    assert op_count[0] == count[0], f"Optimized: {op_count[0]}, Original: {count[0]}"
    
    print("-"*40)
    print("\n")
# Out:
# Number of intervals: 5
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.000000 seconds
# ----------------------------------------
#
#
# Number of intervals: 105
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.000000 seconds
# ----------------------------------------
#
#
# Number of intervals: 205
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.000000 seconds
# ----------------------------------------
#
#
# Number of intervals: 305
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.000000 seconds
# ----------------------------------------
#
#
# Number of intervals: 405
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.000000 seconds
# ----------------------------------------
#
#
# Number of intervals: 505
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.000998 seconds
# ----------------------------------------
#
#
# Number of intervals: 605
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.001005 seconds
# ----------------------------------------
#
#
# Number of intervals: 705
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.001000 seconds
# ----------------------------------------
#
#
# Number of intervals: 805
# Function optimized_count_times took 0.000998 seconds
# Function count_times took 0.000995 seconds
# ----------------------------------------
#
#
# Number of intervals: 905
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.001995 seconds
# ----------------------------------------
#
#
# Number of intervals: 1005
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.003001 seconds
# ----------------------------------------
#
#
# Number of intervals: 1105
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.002999 seconds
# ----------------------------------------
#
#
# Number of intervals: 1205
# Function optimized_count_times took 0.001000 seconds
# Function count_times took 0.003001 seconds
# ----------------------------------------
#
#
# Number of intervals: 1305
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.004001 seconds
# ----------------------------------------
#
#
# Number of intervals: 1405
# Function optimized_count_times took 0.000997 seconds
# Function count_times took 0.003999 seconds
# ----------------------------------------
#
#
# Number of intervals: 1505
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.004004 seconds
# ----------------------------------------
#
#
# Number of intervals: 1605
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.005000 seconds
# ----------------------------------------
#
#
# Number of intervals: 1705
# Function optimized_count_times took 0.000995 seconds
# Function count_times took 0.005002 seconds
# ----------------------------------------
#
#
# Number of intervals: 1805
# Function optimized_count_times took 0.001005 seconds
# Function count_times took 0.005147 seconds
# ----------------------------------------
#
#
# Number of intervals: 1905
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.005993 seconds
# ----------------------------------------
#
#
# Number of intervals: 2005
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.005997 seconds
# ----------------------------------------
#
#
# Number of intervals: 2105
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.007998 seconds
# ----------------------------------------
#
#
# Number of intervals: 2205
# Function optimized_count_times took 0.000998 seconds
# Function count_times took 0.008004 seconds
# ----------------------------------------
#
#
# Number of intervals: 2305
# Function optimized_count_times took 0.001001 seconds
# Function count_times took 0.008000 seconds
# ----------------------------------------
#
#
# Number of intervals: 2405
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.011002 seconds
# ----------------------------------------
#
#
# Number of intervals: 2505
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.009997 seconds
# ----------------------------------------
#
#
# Number of intervals: 2605
# Function optimized_count_times took 0.001004 seconds
# Function count_times took 0.017096 seconds
# ----------------------------------------
#
#
# Number of intervals: 2705
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.013988 seconds
# ----------------------------------------
#
#
# Number of intervals: 2805
# Function optimized_count_times took 0.001002 seconds
# Function count_times took 0.018003 seconds
# ----------------------------------------
#
#
# Number of intervals: 2905
# Function optimized_count_times took 0.000999 seconds
# Function count_times took 0.014987 seconds
# ----------------------------------------
#
#
# Number of intervals: 3005
# Function optimized_count_times took 0.000000 seconds
# Function count_times took 0.014002 seconds
# ----------------------------------------
#
#
# Number of intervals: 3105
# Function optimized_count_times took 0.001001 seconds
# Function count_times took 0.018000 seconds
# ----------------------------------------
#
#
# Number of intervals: 3205
# Function optimized_count_times took 0.001002 seconds
# Function count_times took 0.018119 seconds
# ----------------------------------------
#
#
# Number of intervals: 3305
# Function optimized_count_times took 0.001000 seconds
# Function count_times took 0.018997 seconds
# ----------------------------------------
#
#
# Number of intervals: 3405
# Function optimized_count_times took 0.001003 seconds
# Function count_times took 0.020000 seconds
# ----------------------------------------
#
#
# Number of intervals: 3505
# Function optimized_count_times took 0.001000 seconds
# Function count_times took 0.021892 seconds
# ----------------------------------------
#
#
# Number of intervals: 3605
# Function optimized_count_times took 0.001001 seconds
# Function count_times took 0.020001 seconds
# ----------------------------------------
#
#
# Number of intervals: 3705
# Function optimized_count_times took 0.001001 seconds
# Function count_times took 0.021999 seconds
# ----------------------------------------
#
#
# Number of intervals: 3805
# Function optimized_count_times took 0.001002 seconds
# Function count_times took 0.023998 seconds
# ----------------------------------------
#
#
# Number of intervals: 3905
# Function optimized_count_times took 0.001001 seconds
# Function count_times took 0.026006 seconds
# ----------------------------------------
#
#
# Number of intervals: 4005
# Function optimized_count_times took 0.001001 seconds
# Function count_times took 0.025001 seconds
# ----------------------------------------
#
#
# Number of intervals: 4105
# Function optimized_count_times took 0.000996 seconds
# Function count_times took 0.026068 seconds
# ----------------------------------------
#
#
# Number of intervals: 4205
# Function optimized_count_times took 0.001001 seconds
# Function count_times took 0.032008 seconds
# ----------------------------------------
#
#
# Number of intervals: 4305
# Function optimized_count_times took 0.000998 seconds
# Function count_times took 0.029963 seconds
# ----------------------------------------
#
#
# Number of intervals: 4405
# Function optimized_count_times took 0.001001 seconds
# Function count_times took 0.033002 seconds
# ----------------------------------------
#
#
# Number of intervals: 4505
# Function optimized_count_times took 0.000995 seconds
# Function count_times took 0.032001 seconds
# ----------------------------------------
#
#
# Number of intervals: 4605
# Function optimized_count_times took 0.001006 seconds
# Function count_times took 0.035076 seconds
# ----------------------------------------
#
#
# Number of intervals: 4705
# Function optimized_count_times took 0.001002 seconds
# Function count_times took 0.036000 seconds
# ----------------------------------------
#
#
# Number of intervals: 4805
# Function optimized_count_times took 0.000999 seconds
# Function count_times took 0.038000 seconds
# ----------------------------------------
#
#
# Number of intervals: 4905
# Function optimized_count_times took 0.000999 seconds
# Function count_times took 0.038998 seconds
# ----------------------------------------
#
#
# Number of intervals: 5005
# Function optimized_count_times took 0.000998 seconds
# Function count_times took 0.046001 seconds
# ----------------------------------------
#
#
# Number of intervals: 5105
# Function optimized_count_times took 0.000996 seconds
# Function count_times took 0.039998 seconds
# ----------------------------------------
#
#
# Number of intervals: 5205
# Function optimized_count_times took 0.001000 seconds
# Function count_times took 0.040998 seconds
# ----------------------------------------
#
#
# Number of intervals: 5305
# Function optimized_count_times took 0.001001 seconds
# Function count_times took 0.045000 seconds
# ----------------------------------------
#
#
# Number of intervals: 5405
# Function optimized_count_times took 0.001001 seconds
# Function count_times took 0.047005 seconds
# ----------------------------------------
#
#
# Number of intervals: 5505
# Function optimized_count_times took 0.000999 seconds
# Function count_times took 0.064009 seconds
# ----------------------------------------
#
#
# Number of intervals: 5605
# Function optimized_count_times took 0.001999 seconds
# Function count_times took 0.052996 seconds
# ----------------------------------------
#
#
# Number of intervals: 5705
# Function optimized_count_times took 0.001001 seconds
# Function count_times took 0.054111 seconds
# ----------------------------------------
#
#
# Number of intervals: 5805
# Function optimized_count_times took 0.002001 seconds
# Function count_times took 0.056653 seconds
# ----------------------------------------
#
#
# Number of intervals: 5905
# Function optimized_count_times took 0.001994 seconds
# Function count_times took 0.055000 seconds
# ----------------------------------------
#
#
# Number of intervals: 6005
# Function optimized_count_times took 0.001003 seconds
# Function count_times took 0.056999 seconds
# ----------------------------------------
#
#
# Number of intervals: 6105
# Function optimized_count_times took 0.000997 seconds
# Function count_times took 0.058000 seconds
# ----------------------------------------
#
#
# Number of intervals: 6205
# Function optimized_count_times took 0.000999 seconds
# Function count_times took 0.057999 seconds
# ----------------------------------------
#
#
# Number of intervals: 6305
# Function optimized_count_times took 0.000998 seconds
# Function count_times took 0.064002 seconds
# ----------------------------------------
#
#
# Number of intervals: 6405
# Function optimized_count_times took 0.001997 seconds
# Function count_times took 0.065004 seconds
# ----------------------------------------
#
#
# Number of intervals: 6505
# Function optimized_count_times took 0.001995 seconds
# Function count_times took 0.070001 seconds
# ----------------------------------------
#
#
# Number of intervals: 6605
# Function optimized_count_times took 0.001001 seconds
# Function count_times took 0.071001 seconds
# ----------------------------------------
#
#
# Number of intervals: 6705
# Function optimized_count_times took 0.001998 seconds
# Function count_times took 0.079000 seconds
# ----------------------------------------
#
#
# Number of intervals: 6805
# Function optimized_count_times took 0.001007 seconds
# Function count_times took 0.069993 seconds
# ----------------------------------------
#
#
# Number of intervals: 6905
# Function optimized_count_times took 0.001001 seconds
# Function count_times took 0.080000 seconds
# ----------------------------------------
#
#
# Number of intervals: 7005
# Function optimized_count_times took 0.001001 seconds
# Function count_times took 0.077001 seconds
# ----------------------------------------
#
#
# Number of intervals: 7105
# Function optimized_count_times took 0.000999 seconds
# Function count_times took 0.076253 seconds
# ----------------------------------------
#
#
# Number of intervals: 7205
# Function optimized_count_times took 0.002000 seconds
# Function count_times took 0.088000 seconds
# ----------------------------------------
#
#
# Number of intervals: 7305
# Function optimized_count_times took 0.002003 seconds
# Function count_times took 0.082998 seconds
# ----------------------------------------
#
#
# Number of intervals: 7405
# Function optimized_count_times took 0.002003 seconds
# Function count_times took 0.103009 seconds
# ----------------------------------------
#
#
# Number of intervals: 7505
# Function optimized_count_times took 0.002001 seconds
# Function count_times took 0.087997 seconds
# ----------------------------------------
#
#
# Number of intervals: 7605
# Function optimized_count_times took 0.002002 seconds
# Function count_times took 0.086999 seconds
# ----------------------------------------
#
#
# Number of intervals: 7705
# Function optimized_count_times took 0.002002 seconds
# Function count_times took 0.090001 seconds
# ----------------------------------------
#
#
# Number of intervals: 7805
# Function optimized_count_times took 0.001999 seconds
# Function count_times took 0.089118 seconds
# ----------------------------------------
#
#
# Number of intervals: 7905
# Function optimized_count_times took 0.002000 seconds
# Function count_times took 0.101998 seconds
# ----------------------------------------
#
#
# Number of intervals: 8005
# Function optimized_count_times took 0.002002 seconds
# Function count_times took 0.113127 seconds
# ----------------------------------------
#
#
# Number of intervals: 8105
# Function optimized_count_times took 0.002002 seconds
# Function count_times took 0.126009 seconds
# ----------------------------------------
#
#
# Number of intervals: 8205
# Function optimized_count_times took 0.001002 seconds
# Function count_times took 0.103998 seconds
# ----------------------------------------
#
#
# Number of intervals: 8305
# Function optimized_count_times took 0.001000 seconds
# Function count_times took 0.108544 seconds
# ----------------------------------------
#
#
# Number of intervals: 8405
# Function optimized_count_times took 0.002000 seconds
# Function count_times took 0.123065 seconds
# ----------------------------------------
#
#
# Number of intervals: 8505
# Function optimized_count_times took 0.002000 seconds
# Function count_times took 0.118001 seconds
# ----------------------------------------
#
#
# Number of intervals: 8605
# Function optimized_count_times took 0.002004 seconds
# Function count_times took 0.118998 seconds
# ----------------------------------------
#
#
# Number of intervals: 8705
# Function optimized_count_times took 0.001000 seconds
# Function count_times took 0.126002 seconds
# ----------------------------------------
#
#
# Number of intervals: 8805
# Function optimized_count_times took 0.001997 seconds
# Function count_times took 0.126763 seconds
# ----------------------------------------
#
#
# Number of intervals: 8905
# Function optimized_count_times took 0.002002 seconds
# Function count_times took 0.130093 seconds
# ----------------------------------------
#
#
# Number of intervals: 9005
# Function optimized_count_times took 0.002003 seconds
# Function count_times took 0.128999 seconds
# ----------------------------------------
#
#
# Number of intervals: 9105
# Function optimized_count_times took 0.002001 seconds
# Function count_times took 0.130091 seconds
# ----------------------------------------
#
#
# Number of intervals: 9205
# Function optimized_count_times took 0.002999 seconds
# Function count_times took 0.135001 seconds
# ----------------------------------------
#
#
# Number of intervals: 9305
# Function optimized_count_times took 0.002004 seconds
# Function count_times took 0.138998 seconds
# ----------------------------------------
#
#
# Number of intervals: 9405
# Function optimized_count_times took 0.002001 seconds
# Function count_times took 0.144000 seconds
# ----------------------------------------
#
#
# Number of intervals: 9505
# Function optimized_count_times took 0.001997 seconds
# Function count_times took 0.149000 seconds
# ----------------------------------------
#
#
# Number of intervals: 9605
# Function optimized_count_times took 0.002002 seconds
# Function count_times took 0.146083 seconds
# ----------------------------------------
#
#
# Number of intervals: 9705
# Function optimized_count_times took 0.001998 seconds
# Function count_times took 0.153001 seconds
# ----------------------------------------
#
#
# Number of intervals: 9805
# Function optimized_count_times took 0.001999 seconds
# Function count_times took 0.151096 seconds
# ----------------------------------------
#
#
# Number of intervals: 9905
# Function optimized_count_times took 0.001996 seconds
# Function count_times took 0.160096 seconds
# ----------------------------------------
